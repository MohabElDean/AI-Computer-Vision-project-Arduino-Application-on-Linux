# %%
import os
import numpy as np
import cv2
import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.callbacks import ModelCheckpoint
import matplotlib.pyplot as plt
import serial
import time

# %%
# Defining the serial COM
SerialObj = serial.Serial('COM3')

SerialObj.baudrate = 115200
SerialObj.bytesize = 8
time.sleep(3)

# %%
#Defining constants
NUM_CLASS = 2
IMAGE_SIZE = (400, 400)
BATCH_SIZE = 32

# %%
# Load training data
def load_data(path):
    images = []
    labels = []
    for filename in os.listdir(path):
        img = cv2.imread(os.path.join(path, filename))
        img = cv2.resize(img, IMAGE_SIZE)  # Resize images to a consistent size
        images.append(img)
        labels.append(path.split('/')[-1])  # Assuming the label is the name of the directory
    return images, labels

def test_image(model, image_path):
    img = cv2.imread(image_path)
    img = cv2.resize(img, IMAGE_SIZE)  # Resize image to match training data size
    img = np.expand_dims(img, axis=0)  # Add batch dimension
    prediction = model.predict(img)
    if np.argmax(prediction) == 0:
        print("Detected object: Apple")
    else:
        print("Detected object: Banana")

# %%
# Paths for the training data
apple_path = "C:/Users/zuzz4/OneDrive/Desktop/data new/train/Apple"
banana_path = "C:/Users/zuzz4/OneDrive/Desktop/data new/train/Banana"
test_path = "C:/Users/zuzz4/OneDrive/Desktop/data new/Test"

# %%
# Load training data
apple_images, apple_labels = load_data(apple_path)
banana_images, banana_labels = load_data(banana_path)

# Combine data and labels
images = np.array(apple_images + banana_images)
labels = np.array(apple_labels + banana_labels)

label_dict = {'Apple': 0, 'Banana': 1}
labels = np.array([label_dict[label] for label in labels])

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(images, labels, test_size=0.2, random_state=42)

# %%
# The CNN model
model = Sequential([
    Conv2D(128, (3, 3), activation='relu', input_shape=(400, 400, 3)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(32, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(64, activation='relu'),
    Dense(2, activation='softmax')
])
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(

# %%
# Chossing the optmizer for the model and compiling it
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
# Saving the best model based on validation accuracy
checkpoint = ModelCheckpoint("cnn_model.keras", monitor='val_accuracy', save_best_only=True, mode='max', verbose=1)

# Train the model
history = model.fit(X_train, y_train, epochs=35, batch_size=32, validation_data=(X_test, y_test), callbacks=[checkpoint])

# Print test accuracy
test_loss, test_acc = model.evaluate(X_test, y_test)
print("Test Accuracy:", test_acc)
# Out:
# Epoch 1/35
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.4887 - loss: 414.3918
# Epoch 1: val_accuracy improved from -inf to 0.46341, saving model to cnn_model.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 36s 6s/step - accuracy: 0.4903 - loss: 399.0576 - val_accuracy: 0.4634 - val_loss: 58.5601
# Epoch 2/35
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.5354 - loss: 72.3806
# Epoch 2: val_accuracy improved from 0.46341 to 0.53659, saving model to cnn_model.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 31s 5s/step - accuracy: 0.5347 - loss: 69.8675 - val_accuracy: 0.5366 - val_loss: 18.7164
# Epoch 3/35
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.5390 - loss: 30.7225
# Epoch 3: val_accuracy did not improve from 0.53659
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 30s 5s/step - accuracy: 0.5378 - loss: 29.1495 - val_accuracy: 0.4634 - val_loss: 1.5205
# Epoch 4/35
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.5820 - loss: 2.2794
# Epoch 4: val_accuracy improved from 0.53659 to 0.78049, saving model to cnn_model.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 33s 6s/step - accuracy: 0.5871 - loss: 2.1773 - val_accuracy: 0.7805 - val_loss: 0.4127
# Epoch 5/35
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.7277 - loss: 0.5935
# Epoch 5: val_accuracy improved from 0.78049 to 0.90244, saving model to cnn_model.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 33s 5s/step - accuracy: 0.7296 - loss: 0.5816 - val_accuracy: 0.9024 - val_loss: 0.2871
# Epoch 6/35
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.8527 - loss: 0.3855
# Epoch 6: val_accuracy improved from 0.90244 to 0.92683, saving model to cnn_model.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 32s 5s/step - accuracy: 0.8525 - loss: 0.3754 - val_accuracy: 0.9268 - val_loss: 0.1986
# Epoch 7/35
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.8792 - loss: 0.2617
# Epoch 7: val_accuracy did not improve from 0.92683
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 31s 5s/step - accuracy: 0.8823 - loss: 0.2505 - val_accuracy: 0.8780 - val_loss: 0.1822
# Epoch 8/35
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.9528 - loss: 0.1187
# Epoch 8: val_accuracy did not improve from 0.92683
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 30s 5s/step - accuracy: 0.9551 - loss: 0.1144 - val_accuracy: 0.8780 - val_loss: 0.1931
# Epoch 9/35
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.9813 - loss: 0.0786
# Epoch 9: val_accuracy improved from 0.92683 to 0.95122, saving model to cnn_model.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 35s 6s/step - accuracy: 0.9804 - loss: 0.0780 - val_accuracy: 0.9512 - val_loss: 0.0594
# Epoch 10/35
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.9670 - loss: 0.0719
# Epoch 10: val_accuracy did not improve from 0.95122
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 30s 5s/step - accuracy: 0.9682 - loss: 0.0707 - val_accuracy: 0.9512 - val_loss: 0.0538
# Epoch 11/35
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.9846 - loss: 0.0468
# Epoch 11: val_accuracy did not improve from 0.95122
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 31s 5s/step - accuracy: 0.9850 - loss: 0.0445 - val_accuracy: 0.8780 - val_loss: 0.6041
# Epoch 12/35
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.9771 - loss: 0.0936
# Epoch 12: val_accuracy did not improve from 0.95122
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 31s 5s/step - accuracy: 0.9759 - loss: 0.0975 - val_accuracy: 0.9512 - val_loss: 0.1073
# Epoch 13/35
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.9365 - loss: 0.2651
# Epoch 13: val_accuracy did not improve from 0.95122
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 31s 5s/step - accuracy: 0.9350 - loss: 0.2630 - val_accuracy: 0.9512 - val_loss: 0.1472
# Epoch 14/35
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.9558 - loss: 0.1633
# Epoch 14: val_accuracy improved from 0.95122 to 0.97561, saving model to cnn_model.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 34s 6s/step - accuracy: 0.9541 - loss: 0.1644 - val_accuracy: 0.9756 - val_loss: 0.1545
# Epoch 15/35
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.9412 - loss: 0.1182
# Epoch 15: val_accuracy did not improve from 0.97561
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 31s 5s/step - accuracy: 0.9435 - loss: 0.1188 - val_accuracy: 0.8780 - val_loss: 0.1643
# Epoch 16/35
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.9535 - loss: 0.0831
# Epoch 16: val_accuracy did not improve from 0.97561
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 30s 5s/step - accuracy: 0.9566 - loss: 0.0784 - val_accuracy: 0.9024 - val_loss: 0.1609
# Epoch 17/35
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.9872 - loss: 0.0306
# Epoch 17: val_accuracy did not improve from 0.97561
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 31s 5s/step - accuracy: 0.9872 - loss: 0.0305 - val_accuracy: 0.9024 - val_loss: 0.1571
# Epoch 18/35
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.9636 - loss: 0.0983
# Epoch 18: val_accuracy did not improve from 0.97561
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 30s 5s/step - accuracy: 0.9644 - loss: 0.1031 - val_accuracy: 0.9024 - val_loss: 0.1659
# Epoch 19/35
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.9837 - loss: 0.0483
# Epoch 19: val_accuracy did not improve from 0.97561
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 31s 5s/step - accuracy: 0.9843 - loss: 0.0462 - val_accuracy: 0.9024 - val_loss: 0.1739
# Epoch 20/35
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 1.0000 - loss: 0.0029
# Epoch 20: val_accuracy did not improve from 0.97561
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 30s 5s/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 0.9024 - val_loss: 0.2392
# Epoch 21/35
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.9923 - loss: 0.0168
# Epoch 21: val_accuracy did not improve from 0.97561
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 30s 5s/step - accuracy: 0.9925 - loss: 0.0163 - val_accuracy: 0.9024 - val_loss: 0.3711
# Epoch 22/35
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 1.0000 - loss: 0.0059
# Epoch 22: val_accuracy did not improve from 0.97561
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 30s 5s/step - accuracy: 1.0000 - loss: 0.0057 - val_accuracy: 0.9024 - val_loss: 0.5985
# Epoch 23/35
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.9949 - loss: 0.0142
# Epoch 23: val_accuracy improved from 0.97561 to 1.00000, saving model to cnn_model.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 33s 6s/step - accuracy: 0.9947 - loss: 0.0142 - val_accuracy: 1.0000 - val_loss: 0.0783
# Epoch 24/35
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 1.0000 - loss: 0.0107
# Epoch 24: val_accuracy did not improve from 1.00000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 30s 5s/step - accuracy: 1.0000 - loss: 0.0108 - val_accuracy: 0.9756 - val_loss: 0.0300
# Epoch 25/35
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.9902 - loss: 0.0192
# Epoch 25: val_accuracy did not improve from 1.00000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 30s 5s/step - accuracy: 0.9899 - loss: 0.0194 - val_accuracy: 0.9756 - val_loss: 0.0351
# Epoch 26/35
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 1.0000 - loss: 0.0171
# Epoch 26: val_accuracy did not improve from 1.00000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 30s 5s/step - accuracy: 1.0000 - loss: 0.0166 - val_accuracy: 0.9756 - val_loss: 0.0274
# Epoch 27/35
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.9923 - loss: 0.0353
# Epoch 27: val_accuracy did not improve from 1.00000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 30s 5s/step - accuracy: 0.9925 - loss: 0.0368 - val_accuracy: 1.0000 - val_loss: 0.0031
# Epoch 28/35
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.9979 - loss: 0.0088
# Epoch 28: val_accuracy did not improve from 1.00000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 30s 5s/step - accuracy: 0.9973 - loss: 0.0101 - val_accuracy: 1.0000 - val_loss: 0.0055
# Epoch 29/35
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.9816 - loss: 0.0856
# Epoch 29: val_accuracy did not improve from 1.00000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 30s 5s/step - accuracy: 0.9816 - loss: 0.0810 - val_accuracy: 0.9756 - val_loss: 0.0486
# Epoch 30/35
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 1.0000 - loss: 0.0052
# Epoch 30: val_accuracy did not improve from 1.00000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 30s 5s/step - accuracy: 1.0000 - loss: 0.0054 - val_accuracy: 0.9756 - val_loss: 0.0347
# Epoch 31/35
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 1.0000 - loss: 0.0092
# Epoch 31: val_accuracy did not improve from 1.00000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 30s 5s/step - accuracy: 1.0000 - loss: 0.0097 - val_accuracy: 0.9512 - val_loss: 0.0649
# Epoch 32/35
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 1.0000 - loss: 0.0107
# Epoch 32: val_accuracy did not improve from 1.00000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 30s 5s/step - accuracy: 1.0000 - loss: 0.0101 - val_accuracy: 0.9756 - val_loss: 0.0346
# Epoch 33/35
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 1.0000 - loss: 0.0027
# Epoch 33: val_accuracy did not improve from 1.00000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 30s 5s/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.9756 - val_loss: 0.0176
# Epoch 34/35
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 1.0000 - loss: 0.0010
# Epoch 34: val_accuracy did not improve from 1.00000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 30s 5s/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 1.0000 - val_loss: 0.0099
# Epoch 35/35
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 1.0000 - loss: 0.0031
# Epoch 35: val_accuracy did not improve from 1.00000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 30s 5s/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 1.0000 - val_loss: 0.0061
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 304ms/step - accuracy: 1.0000 - loss: 0.0081
# Test Accuracy: 1.0
# Found 1 files.

# %%
# Camera Code to capture the photo for testing
import cv2
import os
import time

def capture_and_save_image(folder_path):
    # Create the folder if it doesn't exist
    if not os.path.exists(folder_path):
        os.makedirs(folder_path)

    # Open the default camera (usually 0)
    cap = cv2.VideoCapture(0)

    # Check if the camera is opened successfully
    if not cap.isOpened():
        print("Error: Unable to open camera")
        return

    # Allow the camera to adjust to the lighting conditions (1-second delay)
    time.sleep(1)

    # Capture frame-by-frame
    ret, frame = cap.read()

    # Display the captured frame
    cv2.imshow('Captured Image', frame)
    
    # Save the image to the specified folder path
    image_path = os.path.join(folder_path, 'captured_image.jpg')
    cv2.imwrite(image_path, frame)
    
    print("Image saved successfully at:", image_path)

    # Release the camera and close all OpenCV windows
    cap.release()
    cv2.destroyAllWindows()

# Specify the folder path where the image will be saved
folder_path = r"C:/Users/zuzz4/OneDrive/Desktop/data new/Test"

# Call the function to capture and save the image
capture_and_save_image(folder_path)

# %%
# Load test images
test_dataset_path = "C:/Users/zuzz4/OneDrive/Desktop/data new/Test"
test_images = tf.keras.preprocessing.image_dataset_from_directory(
    test_dataset_path,
    labels=None,
    color_mode='rgb',
    label_mode=None,
    shuffle=False,
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE
)

# %%
# Plotting Cell
# Plot training and validation accuracy
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Plot training and validation loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Make predictions on test images
print("\nPredictions on test images:")
for images in test_images:
    result = model.predict(images)
    print(result)
# Out:
# Predictions on test images:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step
# [[0.04024388 0.9597561 ]]

# %%
# Control for the ServoMotors
if (result[0][0] >= 0.7) and  (result[0][1] <= 0.5) :
    SerialObj.write(b'1')
elif (result[0][1] >= 0.7) and  (result[0][0] <= 0.5):
    SerialObj.write(b'2')
